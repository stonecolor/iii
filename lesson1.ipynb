# %%
#搜尋字串後整理出現文字的次數
with open('./trump_speech.txt') as f:
    speech = f.read()
word_dict = {}
for word in speech.lower().replace(',','').replace('.','').split():
    if word in word_dict:
        word_dict[word] +=1
    else:
        word_dict[word] =1
res = sorted(list(word_dict.items()), key=lambda x: x[1], reverse=True)
res
# Out:
# [('the', 279),
#  ('and', 188),
#  ('to', 157),
#  ('of', 148),
#  ('in', 85),
#  ('we', 76),
#  ('for', 66),
#  ('that', 64),
#  ('our', 56),
#  ('is', 52),
#  ('nations', 49),
#  ('a', 48),
#  ('people', 44),
#  ('their', 44),
#  ('it', 41),
#  ('this', 41),
#  ('united', 38),
#  ('are', 32),
#  ('has', 27),
#  ('all', 26),
#  ('have', 25),
#  ('will', 25),
#  ('states', 24),
#  ('world', 23),
#  ('on', 22),
#  ('but', 22),
#  ('not', 21),
#  ('be', 21),
#  ('its', 20),
#  ('with', 18),
#  ('as', 17),
#  ('more', 16),
#  ('must', 16),
#  ('countries', 16),
#  ('regime', 15),
#  ('citizens', 14),
#  ('i', 14),
#  ('an', 14),
#  ('if', 14),
#  ('from', 13),
#  ('own', 13),
#  ('country', 12),
#  ('every', 12),
#  ('nation', 12),
#  ('they', 11),
#  ('than', 11),
#  ('also', 11),
#  ('support', 11),
#  ('sovereign', 11),
#  ('by', 10),
#  ('strong', 10),
#  ('other', 10),
#  ('time', 10),
#  ('seek', 10),
#  ('or', 10),
#  ('prosperity', 10),
#  ('do', 10),
#  ('america', 10),
#  ('together', 10),
#  ('leaders', 9),
#  ('american', 9),
#  ('these', 9),
#  ('today', 9),
#  ('peace', 9),
#  ('us', 9),
#  ('was', 9),
#  ('security', 9),
#  ('those', 9),
#  ('government', 9),
#  ('respect', 9),
#  ('human', 9),
#  ('can', 9),
#  ('no', 9),
#  ('who', 8),
#  ('been', 8),
#  ('freedom', 8),
#  ('sovereignty', 8),
#  ('many', 8),
#  ('one', 8),
#  ('north', 8),
#  ('thank', 8),
#  ('strength', 7),
#  ('only', 7),
#  ('conflict', 7),
#  ('great', 7),
#  ('let', 7),
#  ('future', 7),
#  ('interests', 7),
#  ('responsible', 7),
#  ('against', 7),
#  ('home', 6),
#  ('very', 6),
#  ('them', 6),
#  ('some', 6),
#  ('terrorists', 6),
#  ('weapons', 6),
#  ('up', 6),
#  ('power', 6),
#  ('rights', 6),
#  ('work', 6),
#  ('safe', 6),
#  ('allies', 6),
#  ('confront', 6),
#  ('cannot', 6),
#  ('entire', 6),
#  ('new', 5),
#  ('here', 5),
#  ('address', 5),
#  ('millions', 5),
#  ('want', 5),
#  ('room', 5),
#  ('before', 5),
#  ('last', 5),
#  ('years', 5),
#  ('which', 5),
#  ('like', 5),
#  ('terror', 5),
#  ('values', 5),
#  ('help', 5),
#  ('independent', 5),
#  ('his', 5),
#  ('take', 5),
#  ('life', 5),
#  ('god', 5),
#  ('first', 5),
#  ('history', 5),
#  ('where', 5),
#  ('defend', 5),
#  ('you', 5),
#  ('prosperous', 5),
#  ('trade', 5),
#  ("iran's", 5),
#  ('fight', 5),
#  ('venezuela', 5),
#  ('president', 4),
#  ('stand', 4),
#  ('assistance', 4),
#  ('ever', 4),
#  ('day', 4),
#  ('at', 4),
#  ('long', 4),
#  ('just', 4),
#  ('military', 4),
#  ('war', 4),
#  ('threats', 4),
#  ('live', 4),
#  ('region', 4),
#  ('represented', 4),
#  ('most', 4),
#  ('systems', 4),
#  ('migration', 4),
#  ('promise', 4),
#  ('lift', 4),
#  ('into', 4),
#  ('free', 4),
#  ('diverse', 4),
#  ('when', 4),
#  ('success', 4),
#  ('even', 4),
#  ('impose', 4),
#  ('use', 4),
#  ('whose', 4),
#  ('rule', 4),
#  ('women', 4),
#  ('middle', 4),
#  ('others', 4),
#  ('goal', 4),
#  ('korea', 4),
#  ('innocent', 4),
#  ('nuclear', 4),
#  ('would', 4),
#  ('what', 4),
#  ('iranian', 4),
#  ('fact', 4),
#  ('neighbors', 4),
#  ('political', 4),
#  ('out', 4),
#  ('—', 4),
#  ('my', 3),
#  ('continue', 3),
#  ('begin', 3),
#  ('reforms', 3),
#  ('announced', 3),
#  ('70', 3),
#  ('problems', 3),
#  ('generations', 3),
#  ('dangers', 3),
#  ('threaten', 3),
#  ('regimes', 3),
#  ('international', 3),
#  ('put', 3),
#  ('both', 3),
#  ('should', 3),
#  ('so', 3),
#  ('poverty', 3),
#  ('realize', 3),
#  ('two', 3),
#  ('better', 3),
#  ('could', 3),
#  ('preserve', 3),
#  ('promote', 3),
#  ('beautiful', 3),
#  ('members', 3),
#  ('foundation', 3),
#  ('different', 3),
#  ('allow', 3),
#  ('way', 3),
#  ('example', 3),
#  ('constitution', 3),
#  ('americans', 3),
#  ('duty', 3),
#  ('always', 3),
#  ('best', 3),
#  ('peaceful', 3),
#  ('especially', 3),
#  ('deal', 3),
#  ('return', 3),
#  ('hold', 3),
#  ("america's", 3),
#  ('fought', 3),
#  ('east', 3),
#  ('hope', 3),
#  ('down', 3),
#  ('path', 3),
#  ('challenges', 3),
#  ('face', 3),
#  ('culture', 3),
#  ('evil', 3),
#  ('destruction', 3),
#  ('were', 3),
#  ('missiles', 3),
#  ('council', 3),
#  ('sanctions', 3),
#  ('much', 3),
#  ('corrupt', 3),
#  ('dictatorship', 3),
#  ('democracy', 3),
#  ('end', 3),
#  ('stop', 3),
#  ('tear', 3),
#  ('once', 3),
#  ('finance', 3),
#  ('isis', 3),
#  ('syrian', 3),
#  ('including', 3),
#  ('humanitarian', 3),
#  ('led', 3),
#  ('global', 3),
#  ('under', 3),
#  ('maduro', 3),
#  ('venezuelan', 3),
#  ('socialism', 3),
#  ('forgotten', 3),
#  ('bless', 3),
#  ('mr', 2),
#  ('secretary', 2),
#  ('general', 2),
#  ('leader', 2),
#  ('emerge', 2),
#  ('well', 2),
#  ('since', 2),
#  ('because', 2),
#  ('working', 2),
#  ('soon', 2),
#  ('stood', 2),
#  ('opportunity', 2),
#  ('technology', 2),
#  ('solve', 2),
#  ('gathered', 2),
#  ('spread', 2),
#  ('planet', 2),
#  ('rogue', 2),
#  ('body', 2),
#  ('humanity', 2),
#  ('authoritarian', 2),
#  ('collapse', 2),
#  ('toward', 2),
#  ('criminal', 2),
#  ('mass', 2),
#  ('borders', 2),
#  ('forms', 2),
#  ('dreams', 2),
#  ('ensure', 2),
#  ('children', 2),
#  ('violence', 2),
#  ('fear', 2),
#  ('institution', 2),
#  ('wars', 2),
#  ('based', 2),
#  ('vision', 2),
#  ('protect', 2),
#  ('same', 2),
#  ('ago', 2),
#  ('marshall', 2),
#  ('plan', 2),
#  ('restore', 2),
#  ('europe', 2),
#  ('pillars', 2),
#  ('noble', 2),
#  ('truman', 2),
#  ('said', 2),
#  ('message', 2),
#  ('full', 2),
#  ('depends', 2),
#  ('overcome', 2),
#  ('present', 2),
#  ('past', 2),
#  ('embrace', 2),
#  ('expect', 2),
#  ('share', 2),
#  ('cultures', 2),
#  ('uphold', 2),
#  ('duties', 2),
#  ('cooperation', 2),
#  ('side', 2),
#  ('destiny', 2),
#  ('intended', 2),
#  ('rather', 2),
#  ('watch', 2),
#  ('pride', 2),
#  ('countless', 2),
#  ('around', 2),
#  ('globe', 2),
#  ('dignity', 2),
#  ('law', 2),
#  ('words', 2),
#  ('sacrificed', 2),
#  ('elected', 2),
#  ('belongs', 2),
#  ('renewing', 2),
#  ('founding', 2),
#  ('principle', 2),
#  ('serve', 2),
#  ('safety', 2),
#  ('your', 2),
#  ('state', 2),
#  ('close', 2),
#  ('harmony', 2),
#  ('forever', 2),
#  ('friend', 2),
#  ('taken', 2),
#  ('one-sided', 2),
#  ('above', 2),
#  ('secure', 2),
#  ('men', 2),
#  ('build', 2),
#  ('institutions', 2),
#  ('such', 2),
#  ('ideologies', 2),
#  ('realism', 2),
#  ('rooted', 2),
#  ('forces', 2),
#  ('question', 2),
#  ('enough', 2),
#  ('then', 2),
#  ('faithfully', 2),
#  ('south', 2),
#  ('china', 2),
#  ('engagement', 2),
#  ('threatens', 2),
#  ('chaos', 2),
#  ('few', 2),
#  ('decent', 2),
#  ('well-being', 2),
#  ("regime's", 2),
#  ('student', 2),
#  ('die', 2),
#  ('banned', 2),
#  ('her', 2),
#  ("korea's", 2),
#  ('now', 2),
#  ('reckless', 2),
#  ('pursuit', 2),
#  ('arm', 2),
#  ('financially', 2),
#  ('itself', 2),
#  ('choice', 2),
#  ('totally', 2),
#  ('mission', 2),
#  ('willing', 2),
#  ('necessary', 2),
#  ("that's", 2),
#  ('recently', 2),
#  ('until', 2),
#  ('far', 2),
#  ('death', 2),
#  ('behind', 2),
#  ('bloodshed', 2),
#  ('fund', 2),
#  ('hezbollah', 2),
#  ('attack', 2),
#  ('arab', 2),
#  ('wealth', 2),
#  ('bashar', 2),
#  ('throughout', 2),
#  ('destabilizing', 2),
#  ('while', 2),
#  ('eventual', 2),
#  ('iran', 2),
#  ('embarrassment', 2),
#  ('believe', 2),
#  ('good', 2),
#  ('recent', 2),
#  ('terrorism', 2),
#  ('islamic', 2),
#  ('any', 2),
#  ('ideology', 2),
#  ('groups', 2),
#  ('taliban', 2),
#  ('victory', 2),
#  ('rules', 2),
#  ('made', 2),
#  ('chemical', 2),
#  ('person', 2),
#  ('why', 2),
#  ('providing', 2),
#  ('vital', 2),
#  ('role', 2),
#  ('hosting', 2),
#  ('refugees', 2),
#  ('billions', 2),
#  ('approach', 2),
#  ('refugee', 2),
#  ('part', 2),
#  ('process', 2),
#  ('cost', 2),
#  ('hearts', 2),
#  ('western', 2),
#  ('hemisphere', 2),
#  ('over', 2),
#  ('uncontrolled', 2),
#  ('unfair', 2),
#  ('sending', 2),
#  ('receiving', 2),
#  ('pursue', 2),
#  ('economic', 2),
#  ('reform', 2),
#  ('often', 2),
#  ('union', 2),
#  ('relief', 2),
#  ('invested', 2),
#  ('health', 2),
#  ('initiative', 2),
#  ('commitment', 2),
#  ('effective', 2),
#  ('confronting', 2),
#  ('too', 2),
#  ('organization', 2),
#  ('source', 2),
#  ('pay', 2),
#  ('burden', 2),
#  ('fair', 2),
#  ('powerful', 2),
#  ('accountable', 2),
#  ('societies', 2),
#  ('cuba', 2),
#  ('cuban', 2),
#  ('socialist', 2),
#  ('suffering', 2),
#  ('destroyed', 2),
#  ('important', 2),
#  ('prepared', 2),
#  ('action', 2),
#  ('healthy', 2),
#  ('bond', 2),
#  ('call', 2),
#  ('implemented', 2),
#  ('never', 2),
#  ('sacrifice', 2),
#  ('ourselves', 2),
#  ('distinguished', 1),
#  ('delegates', 1),
#  ('welcome', 1),
#  ('york', 1),
#  ('profound', 1),
#  ('honor', 1),
#  ('city', 1),
#  ('representative', 1),
#  ('suffer', 1),
#  ('effects', 1),
#  ('devastating', 1),
#  ('hurricanes', 1),
#  ('struck', 1),
#  ('expressing', 1),
#  ('appreciation', 1),
#  ('offered', 1),
#  ('aid', 1),
#  ('resilient', 1),
#  ('hardships', 1),
#  ('determined', 1),
#  ('fortunately', 1),
#  ('done', 1),
#  ('election', 1),
#  ('november', 1),
#  ('8', 1),
#  ('stock', 1),
#  ('market', 1),
#  ('all-time', 1),
#  ('high', 1),
#  ('record', 1),
#  ('unemployment', 1),
#  ('lowest', 1),
#  ('level', 1),
#  ('16', 1),
#  ('regulatory', 1),
#  ('companies', 1),
#  ('moving', 1),
#  ('back', 1),
#  ('creating', 1),
#  ('job', 1),
#  ('growth', 1),
#  ('likes', 1),
#  ('seen', 1),
#  ('spending', 1),
#  ('almost', 1),
#  ('$700', 1),
#  ('billion', 1),
#  ('defense', 1),
#  ('strongest', 1),
#  ('times', 1),
#  ('movements', 1),
#  ('religions', 1),
#  ('assembly', 1),
#  ('intend', 1),
#  ('serious', 1),
#  ('enormous', 1),
#  ('potential', 1),
#  ('waiting', 1),
#  ('unleashed', 1),
#  ('extraordinary', 1),
#  ('breakthroughs', 1),
#  ('science', 1),
#  ('medicine', 1),
#  ('curing', 1),
#  ('illnesses', 1),
#  ('solving', 1),
#  ('prior', 1),
#  ('thought', 1),
#  ('impossible', 1),
#  ('each', 1),
#  ('brings', 1),
#  ('news', 1),
#  ('growing', 1),
#  ('everything', 1),
#  ('cherish', 1),
#  ('value', 1),
#  ('extremists', 1),
#  ('destructive', 1),
#  ('known', 1),
#  ('authority', 1),
#  ('powers', 1),
#  ('alliances', 1),
#  ('prevented', 1),
#  ('tilted', 1),
#  ('word', 1),
#  ('ii', 1),
#  ('networks', 1),
#  ('traffic', 1),
#  ('drugs', 1),
#  ('force', 1),
#  ('dislocation', 1),
#  ('aggression', 1),
#  ('exploit', 1),
#  ('menace', 1),
#  ('simply', 1),
#  ('meet', 1),
#  ('immense', 1),
#  ('peril', 1),
#  ('entirely', 1),
#  ('whether', 1),
#  ('heights', 1),
#  ('fall', 1),
#  ('valley', 1),
#  ('disrepair', 1),
#  ('choose', 1),
#  ('raised', 1),
#  ('hatred', 1),
#  ('founded', 1),
#  ('aftermath', 1),
#  ('shape', 1),
#  ('cooperate', 1),
#  ('period', 1),
#  ('exactly', 1),
#  ('developed', 1),
#  ('built', 1),
#  ('idea', 1),
#  ('whole', 1),
#  ('safer', 1),
#  ('congress', 1),
#  ('european', 1),
#  ('recovery', 1),
#  ('accord', 1),
#  ('upon', 1),
#  ('perils', 1),
#  ('achieve', 1),
#  ('wisdom', 1),
#  ('coalition', 1),
#  ('themselves', 1),
#  ('traditions', 1),
#  ('core', 1),
#  ('coexist', 1),
#  ('basis', 1),
#  ('mutual', 1),
#  ('ownership', 1),
#  ('control', 1),
#  ('individuals', 1),
#  ('flourish', 1),
#  ('fullness', 1),
#  ('anyone', 1),
#  ('shine', 1),
#  ('everyone', 1),
#  ('week', 1),
#  ('gives', 1),
#  ('special', 1),
#  ('reason', 1),
#  ('celebrating', 1),
#  ('230th', 1),
#  ('anniversary', 1),
#  ('beloved', 1),
#  ('oldest', 1),
#  ('still', 1),
#  ('timeless', 1),
#  ('document', 1),
#  ('found', 1),
#  ('inspiration', 1),
#  ('nature', 1),
#  ('greatest', 1),
#  ('three', 1),
#  ('"we', 1),
#  ('people"', 1),
#  ('maintain', 1),
#  ('govern', 1),
#  ('give', 1),
#  ('foreign', 1),
#  ('affairs', 1),
#  ("government's", 1),
#  ('needs', 1),
#  ('obligation', 1),
#  ('remains', 1),
#  ('vehicle', 1),
#  ('elevating', 1),
#  ('condition', 1),
#  ('making', 1),
#  ('requires', 1),
#  ('unity', 1),
#  ('create', 1),
#  ('longer', 1),
#  ('advantage', 1),
#  ('enter', 1),
#  ('gets', 1),
#  ('nothing', 1),
#  ('office', 1),
#  ('else', 1),
#  ('fulfilling', 1),
#  ('obligations', 1),
#  ("it's", 1),
#  ("everyone's", 1),
#  ('does', 1),
#  ('speak', 1),
#  ('expressed', 1),
#  ('charter', 1),
#  ('paid', 1),
#  ('ultimate', 1),
#  ('price', 1),
#  ('hall', 1),
#  ('devotion', 1),
#  ('measured', 1),
#  ('battlefields', 1),
#  ('young', 1),
#  ('alongside', 1),
#  ('beaches', 1),
#  ('deserts', 1),
#  ('jungles', 1),
#  ('asia', 1),
#  ('eternal', 1),
#  ('credit', 1),
#  ('character', 1),
#  ('after', 1),
#  ('victorious', 1),
#  ('bloodiest', 1),
#  ('did', 1),
#  ('territorial', 1),
#  ('expansion', 1),
#  ('attempt', 1),
#  ('oppose', 1),
#  ('instead', 1),
#  ('helped', 1),
#  ('friendship', 1),
#  ('strife', 1),
#  ('guided', 1),
#  ('outcomes', 1),
#  ('policy', 1),
#  ('principled', 1),
#  ('shared', 1),
#  ('facing', 1),
#  ('escape', 1),
#  ('avoid', 1),
#  ('slide', 1),
#  ('complacency', 1),
#  ('numb', 1),
#  ('enjoy', 1),
#  ('tomorrow', 1),
#  ('desire', 1),
#  ('aspire', 1),
#  ('approval', 1),
#  ('fulfill', 1),
#  ('represent', 1),
#  ('futures', 1),
#  ('reject', 1),
#  ('ukraine', 1),
#  ('sea', 1),
#  ('founders', 1),
#  ('turmoil', 1),
#  ('score', 1),
#  ('small', 1),
#  ('violate', 1),
#  ('neither', 1),
#  ('nor', 1),
#  ('righteous', 1),
#  ('wicked', 1),
#  ('triumph', 1),
#  ('become', 1),
#  ('bystanders', 1),
#  ('gather', 1),
#  ('shown', 1),
#  ('contempt', 1),
#  ('depraved', 1),
#  ('starvation', 1),
#  ('deaths', 1),
#  ('koreans', 1),
#  ('imprisonment', 1),
#  ('torture', 1),
#  ('killing', 1),
#  ('oppression', 1),
#  ('witness', 1),
#  ('deadly', 1),
#  ('abuse', 1),
#  ('college', 1),
#  ('otto', 1),
#  ('warmbier', 1),
#  ('returned', 1),
#  ('days', 1),
#  ('later', 1),
#  ('saw', 1),
#  ('assassination', 1),
#  ("dictator's", 1),
#  ('brother', 1),
#  ('using', 1),
#  ('nerve', 1),
#  ('agents', 1),
#  ('airport', 1),
#  ('know', 1),
#  ('kidnapped', 1),
#  ('sweet', 1),
#  ('13-year-old', 1),
#  ('japanese', 1),
#  ('girl', 1),
#  ('beach', 1),
#  ('enslave', 1),
#  ('language', 1),
#  ('tutor', 1),
#  ('spies', 1),
#  ('twisted', 1),
#  ('ballistic', 1),
#  ('unthinkable', 1),
#  ('loss', 1),
#  ('outrage', 1),
#  ('supply', 1),
#  ('imperils', 1),
#  ('earth', 1),
#  ('interest', 1),
#  ('seeing', 1),
#  ('band', 1),
#  ('criminals', 1),
#  ('patience', 1),
#  ('forced', 1),
#  ('destroy', 1),
#  ('rocket', 1),
#  ('man', 1),
#  ('suicide', 1),
#  ('himself', 1),
#  ('ready', 1),
#  ('able', 1),
#  ('hopefully', 1),
#  ('about', 1),
#  ("let's", 1),
#  ('see', 1),
#  ('how', 1),
#  ('denuclearization', 1),
#  ('acceptable', 1),
#  ('held', 1),
#  ('unanimous', 1),
#  ('15-0', 1),
#  ('votes', 1),
#  ('adopting', 1),
#  ('hard-hitting', 1),
#  ('resolutions', 1),
#  ('russia', 1),
#  ('joining', 1),
#  ('vote', 1),
#  ('along', 1),
#  ('involved', 1),
#  ('isolate', 1),
#  ('kim', 1),
#  ('ceases', 1),
#  ('hostile', 1),
#  ('behavior', 1),
#  ('decision', 1),
#  ('korea;', 1),
#  ('another', 1),
#  ('speaks', 1),
#  ('openly', 1),
#  ('murder', 1),
#  ('vowing', 1),
#  ('israel', 1),
#  ('ruin', 1),
#  ('masks', 1),
#  ('false', 1),
#  ('guise', 1),
#  ('turned', 1),
#  ('wealthy', 1),
#  ('rich', 1),
#  ('economically', 1),
#  ('depleted', 1),
#  ('chief', 1),
#  ('exports', 1),
#  ('longest-suffering', 1),
#  ('victims', 1),
#  ('resources', 1),
#  ('improve', 1),
#  ('oil', 1),
#  ('profits', 1),
#  ('go', 1),
#  ('kill', 1),
#  ('muslims', 1),
#  ('israeli', 1),
#  ('rightly', 1),
#  ('goes', 1),
#  ('shore', 1),
#  ("al-assad's", 1),
#  ('fuel', 1),
#  ("yemen's", 1),
#  ('civil', 1),
#  ('undermine', 1),
#  ('murderous', 1),
#  ('activities', 1),
#  ('building', 1),
#  ('dangerous', 1),
#  ('abide', 1),
#  ('agreement', 1),
#  ('provides', 1),
#  ('cover', 1),
#  ('construction', 1),
#  ('program', 1),
#  ('worst', 1),
#  ('transactions', 1),
#  ('entered', 1),
#  ('frankly', 1),
#  ("don't", 1),
#  ('think', 1),
#  ("you've", 1),
#  ('heard', 1),
#  ('me', 1),
#  ('join', 1),
#  ('demanding', 1),
#  ('unjustly', 1),
#  ('detained', 1),
#  ('supporting', 1),
#  ('serving', 1),
#  ('understands', 1),
#  ('change', 1),
#  ('vast', 1),
#  ('causes', 1),
#  ('restrict', 1),
#  ('internet', 1),
#  ('access', 1),
#  ('satellite', 1),
#  ('dishes', 1),
#  ('shoot', 1),
#  ('unarmed', 1),
#  ('protesters', 1),
#  ('imprison', 1),
#  ('reformers', 1),
#  ('oppressive', 1),
#  ('endure', 1),
#  ('come', 1),
#  ("nation's", 1),
#  ('proud', 1),
#  ('roots', 1),
#  ('center', 1),
#  ('civilization', 1),
#  ('happy', 1),
#  ('again?', 1),
#  ('stark', 1),
#  ('contrast', 1),
#  ('commitments', 1),
#  ('halt', 1),
#  ('saudi', 1),
#  ('arabia', 1),
#  ('early', 1),
#  ('year', 1),
#  ('greatly', 1),
#  ('honored', 1),
#  ('50', 1),
#  ('muslim', 1),
#  ('agreed', 1),
#  ('extremism', 1),
#  ('inspires', 1),
#  ('radical', 1),
#  ('indeed', 1),
#  ('deny', 1),
#  ('haven', 1),
#  ('transit', 1),
#  ('funding', 1),
#  ('form', 1),
#  ('vile', 1),
#  ('sinister', 1),
#  ('drive', 1),
#  ('expose', 1),
#  ('fi', 1),
#  ('al-qaeda', 1),
#  ('slaughter', 1),
#  ('crush', 1),
#  ('loser', 1),
#  ('reemergence', 1),
#  ('havens', 1),
#  ('launch', 1),
#  ('attacks', 1),
#  ('month', 1),
#  ('strategy', 1),
#  ('afghanistan', 1),
#  ('dictate', 1),
#  ('length', 1),
#  ('scope', 1),
#  ('operation', 1),
#  ('arbitrary', 1),
#  ('benchmarks', 1),
#  ('timetables', 1),
#  ('set', 1),
#  ('politicians', 1),
#  ('changed', 1),
#  ('terrorist', 1),
#  ('syria', 1),
#  ('iraq', 1),
#  ('big', 1),
#  ('gains', 1),
#  ('lasting', 1),
#  ('defeat', 1),
#  ('achieved', 1),
#  ('eight', 1),
#  ('months', 1),
#  ('combined', 1),
#  ('deescalation', 1),
#  ('solution', 1),
#  ('honors', 1),
#  ('actions', 1),
#  ('al-assad', 1),
#  ('shock', 1),
#  ('conscience', 1),
#  ('society', 1),
#  ('allowed', 1),
#  ('carried', 1),
#  ('missile', 1),
#  ('strike', 1),
#  ('airbase', 1),
#  ('launched', 1),
#  ('appreciate', 1),
#  ('efforts', 1),
#  ('agencies', 1),
#  ('areas', 1),
#  ('liberated', 1),
#  ('jordan', 1),
#  ('turkey', 1),
#  ('lebanon', 1),
#  ('compassionate', 1),
#  ('spent', 1),
#  ('dollars', 1),
#  ('helping', 1),
#  ('effort', 1),
#  ('resettlement', 1),
#  ('designed', 1),
#  ('horribly', 1),
#  ('treated', 1),
#  ('enables', 1),
#  ('rebuilding', 1),
#  ('resettling', 1),
#  ('assist', 1),
#  ('10', 1),
#  ('goodness', 1),
#  ('offer', 1),
#  ('financial', 1),
#  ('agreements', 1),
#  ('g20', 1),
#  ('host', 1),
#  ('possible', 1),
#  ('decades', 1),
#  ('dealt', 1),
#  ('learned', 1),
#  ('term', 1),
#  ('deeply', 1),
#  ...]

# %%
#STOPWORDS
stopwords_str = """a
about
above
across
after
afterwards
again
against
all
almost
alone
along
already
also
although
always
am
among
amongst
amoungst
amount
an
and
another
any
anyhow
anyone
anything
anyway
anywhere
are
around
as
at
back
be
became
because
become
becomes
becoming
been
before
beforehand
behind
being
below
beside
besides
between
beyond
bill
both
bottom
but
by
call
can
cannot
cant
co
computer
con
could
couldnt
cry
de
describe
detail
do
done
down
due
during
each
eg
eight
either
eleven
else
elsewhere
empty
enough
etc
even
ever
every
everyone
everything
everywhere
except
few
fifteen
fify
fill
find
fire
first
five
for
former
formerly
forty
found
four
from
front
full
further
get
give
go
had
has
hasnt
have
he
hence
her
here
hereafter
hereby
herein
hereupon
hers
herse"
him
himse"
his
how
however
hundred
i
ie
if
in
inc
indeed
interest
into
is
it
its
itse"
keep
last
latter
latterly
least
less
ltd
made
many
may
me
meanwhile
might
mill
mine
more
moreover
most
mostly
move
much
must
my
myse"
name
namely
neither
never
nevertheless
next
nine
no
nobody
none
noone
nor
not
nothing
now
nowhere
of
off
often
on
once
one
only
onto
or
other
others
otherwise
our
ours
ourselves
out
over
own
part
per
perhaps
please
put
rather
re
same
see
seem
seemed
seeming
seems
serious
several
she
should
show
side
since
sincere
six
sixty
so
some
somehow
someone
something
sometime
sometimes
somewhere
still
such
system
take
ten
than
that
the
their
them
themselves
then
thence
there
thereafter
thereby
therefore
therein
thereupon
these
they
thick
thin
third
this
those
though
three
through
throughout
thru
thus
to
together
too
top
toward
towards
twelve
twenty
two
un
under
until
up
upon
us
very
via
was
we
well
were
what
whatever
when
whence
whenever
where
whereafter
whereas
whereby
wherein
whereupon
wherever
whether
which
while
whither
who
whoever
whole
whom
whose
why
will
with
within
without
would
yet
you
your
yours
yourself
yourselves"""

stopwords = stopwords_str.split()
stopwords
# Out:
# ['a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amoungst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'bill',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'call',
#  'can',
#  'cannot',
#  'cant',
#  'co',
#  'computer',
#  'con',
#  'could',
#  'couldnt',
#  'cry',
#  'de',
#  'describe',
#  'detail',
#  'do',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eg',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'etc',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fify',
#  'fill',
#  'find',
#  'fire',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'found',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'hasnt',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herse"',
#  'him',
#  'himse"',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'ie',
#  'if',
#  'in',
#  'inc',
#  'indeed',
#  'interest',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itse"',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'ltd',
#  'made',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mill',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myse"',
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'rather',
#  're',
#  'same',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'sincere',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'system',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'thick',
#  'thin',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'un',
#  'under',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves']

# %%
#刪除STOPSWORDS後之資料
from collections import Counter
with open('./trump_speech.txt') as f:
    speech = f.read()
word_dict = Counter()
for word in speech.lower().replace(',','').replace('.','').split(' '):
    if word not in stopwords:
        if word in word_dict:
            word_dict[word] += 1
        else:
            word_dict[word] = 1
res = sorted(list(word_dict.items()), key=lambda x: x[1], reverse=True)
res
# Out:
# [('nations', 49),
#  ('people', 43),
#  ('united', 38),
#  ('states', 24),
#  ('world', 23),
#  ('countries', 16),
#  ('regime', 15),
#  ('citizens', 14),
#  ('country', 12),
#  ('nation', 12),
#  ('support', 11),
#  ('sovereign', 11),
#  ('strong', 10),
#  ('time', 10),
#  ('seek', 10),
#  ('prosperity', 10),
#  ('leaders', 9),
#  ('american', 9),
#  ('today', 9),
#  ('peace', 9),
#  ('security', 9),
#  ('government', 9),
#  ('respect', 9),
#  ('america', 9),
#  ('human', 9),
#  ('freedom', 8),
#  ('sovereignty', 8),
#  ('north', 8),
#  ('thank', 8),
#  ('conflict', 7),
#  ('great', 7),
#  ('let', 7),
#  ('future', 7),
#  ('interests', 7),
#  ('responsible', 7),
#  ('home', 6),
#  ('terrorists', 6),
#  ('strength', 6),
#  ('weapons', 6),
#  ('power', 6),
#  ('\nthis', 6),
#  ('rights', 6),
#  ('work', 6),
#  ('safe', 6),
#  ('allies', 6),
#  ('\nwe', 6),
#  ('confront', 6),
#  ('entire', 6),
#  ('new', 5),
#  ('address', 5),
#  ('millions', 5),
#  ('want', 5),
#  ('room', 5),
#  ('years', 5),
#  ('terror', 5),
#  ('values', 5),
#  ('help', 5),
#  ('independent', 5),
#  ('\nthe', 5),
#  ('life', 5),
#  ('god', 5),
#  ('defend', 5),
#  ('prosperous', 5),
#  ('trade', 5),
#  ("iran's", 5),
#  ('fight', 5),
#  ('venezuela', 5),
#  ('president', 4),
#  ('stand', 4),
#  ('assistance', 4),
#  ('day', 4),
#  ('long', 4),
#  ('just', 4),
#  ('military', 4),
#  ('war', 4),
#  ('threats', 4),
#  ('live', 4),
#  ('region', 4),
#  ('represented', 4),
#  ('systems', 4),
#  ('migration', 4),
#  ('promise', 4),
#  ('lift', 4),
#  ('free', 4),
#  ('diverse', 4),
#  ('success', 4),
#  ('impose', 4),
#  ('use', 4),
#  ('rule', 4),
#  ('like', 4),
#  ('women', 4),
#  ('middle', 4),
#  ('history', 4),
#  ('goal', 4),
#  ('korea', 4),
#  ('innocent', 4),
#  ('nuclear', 4),
#  ('iranian', 4),
#  ('fact', 4),
#  ('neighbors', 4),
#  ('political', 4),
#  ('—', 4),
#  ('continue', 3),
#  ('begin', 3),
#  ('reforms', 3),
#  ('announced', 3),
#  ('70', 3),
#  ('problems', 3),
#  ('generations', 3),
#  ('dangers', 3),
#  ('threaten', 3),
#  ('regimes', 3),
#  ('international', 3),
#  ('poverty', 3),
#  ('realize', 3),
#  ('better', 3),
#  ('preserve', 3),
#  ('promote', 3),
#  ('beautiful', 3),
#  ('members', 3),
#  ('foundation', 3),
#  ('different', 3),
#  ('allow', 3),
#  ('way', 3),
#  ('example', 3),
#  ('constitution', 3),
#  ('americans', 3),
#  ('duty', 3),
#  ('best', 3),
#  ('peaceful', 3),
#  ('especially', 3),
#  ('deal', 3),
#  ('return', 3),
#  ('hold', 3),
#  ("america's", 3),
#  ('fought', 3),
#  ('east', 3),
#  ('hope', 3),
#  ('path', 3),
#  ('challenges', 3),
#  ('face', 3),
#  ('culture', 3),
#  ('evil', 3),
#  ('destruction', 3),
#  ('missiles', 3),
#  ('council', 3),
#  ('sanctions', 3),
#  ('corrupt', 3),
#  ('dictatorship', 3),
#  ('democracy', 3),
#  ('end', 3),
#  ('stop', 3),
#  ('tear', 3),
#  ('finance', 3),
#  ('isis', 3),
#  ('syrian', 3),
#  ('including', 3),
#  ('humanitarian', 3),
#  ('led', 3),
#  ('global', 3),
#  ('maduro', 3),
#  ('venezuelan', 3),
#  ('socialism', 3),
#  ('forgotten', 3),
#  ('bless', 3),
#  ('mr', 2),
#  ('secretary', 2),
#  ('general', 2),
#  ('leader', 2),
#  ('emerge', 2),
#  ('working', 2),
#  ('soon', 2),
#  ('stood', 2),
#  ('opportunity', 2),
#  ('technology', 2),
#  ('solve', 2),
#  ('gathered', 2),
#  ('spread', 2),
#  ('planet', 2),
#  ('rogue', 2),
#  ('body', 2),
#  ('humanity', 2),
#  ('authoritarian', 2),
#  ('collapse', 2),
#  ('criminal', 2),
#  ('mass', 2),
#  ('borders', 2),
#  ('forms', 2),
#  ('dreams', 2),
#  ('ensure', 2),
#  ('children', 2),
#  ('violence', 2),
#  ('fear', 2),
#  ('institution', 2),
#  ('wars', 2),
#  ('based', 2),
#  ('vision', 2),
#  ('protect', 2),
#  ('ago', 2),
#  ('marshall', 2),
#  ('plan', 2),
#  ('restore', 2),
#  ('europe', 2),
#  ('pillars', 2),
#  ('noble', 2),
#  ('truman', 2),
#  ('said', 2),
#  ('message', 2),
#  ('depends', 2),
#  ('overcome', 2),
#  ('present', 2),
#  ('past', 2),
#  ('embrace', 2),
#  ('expect', 2),
#  ('share', 2),
#  ('cultures', 2),
#  ('uphold', 2),
#  ('duties', 2),
#  ('cooperation', 2),
#  ('destiny', 2),
#  ('intended', 2),
#  ('watch', 2),
#  ('pride', 2),
#  ('countless', 2),
#  ('globe', 2),
#  ('dignity', 2),
#  ('law', 2),
#  ('words', 2),
#  ('sacrificed', 2),
#  ('elected', 2),
#  ('belongs', 2),
#  ('renewing', 2),
#  ('founding', 2),
#  ('principle', 2),
#  ('serve', 2),
#  ('safety', 2),
#  ('state', 2),
#  ('close', 2),
#  ('harmony', 2),
#  ('forever', 2),
#  ('friend', 2),
#  ('taken', 2),
#  ('one-sided', 2),
#  ('secure', 2),
#  ('men', 2),
#  ('build', 2),
#  ('institutions', 2),
#  ('ideologies', 2),
#  ('realism', 2),
#  ('rooted', 2),
#  ('forces', 2),
#  ('question', 2),
#  ('\nif', 2),
#  ('faithfully', 2),
#  ('south', 2),
#  ('china', 2),
#  ('engagement', 2),
#  ('threatens', 2),
#  ('chaos', 2),
#  ('decent', 2),
#  ('well-being', 2),
#  ("regime's", 2),
#  ('student', 2),
#  ('die', 2),
#  ('banned', 2),
#  ("korea's", 2),
#  ('reckless', 2),
#  ('pursuit', 2),
#  ('arm', 2),
#  ('financially', 2),
#  ('itself', 2),
#  ('choice', 2),
#  ('totally', 2),
#  ('mission', 2),
#  ('willing', 2),
#  ('necessary', 2),
#  ("that's", 2),
#  ('recently', 2),
#  ('far', 2),
#  ('death', 2),
#  ('bloodshed', 2),
#  ('fund', 2),
#  ('hezbollah', 2),
#  ('arab', 2),
#  ('wealth', 2),
#  ('bashar', 2),
#  ('destabilizing', 2),
#  ('eventual', 2),
#  ('iran', 2),
#  ('embarrassment', 2),
#  ('believe', 2),
#  ('good', 2),
#  ('recent', 2),
#  ('terrorism', 2),
#  ('islamic', 2),
#  ('ideology', 2),
#  ('taliban', 2),
#  ('victory', 2),
#  ('rules', 2),
#  ('chemical', 2),
#  ('person', 2),
#  ('providing', 2),
#  ('vital', 2),
#  ('role', 2),
#  ('hosting', 2),
#  ('refugees', 2),
#  ('billions', 2),
#  ('approach', 2),
#  ('refugee', 2),
#  ('process', 2),
#  ('cost', 2),
#  ('hearts', 2),
#  ('western', 2),
#  ('hemisphere', 2),
#  ('uncontrolled', 2),
#  ('unfair', 2),
#  ('sending', 2),
#  ('receiving', 2),
#  ('pursue', 2),
#  ('economic', 2),
#  ('reform', 2),
#  ('union', 2),
#  ('relief', 2),
#  ('invested', 2),
#  ('health', 2),
#  ('initiative', 2),
#  ('commitment', 2),
#  ('effective', 2),
#  ('confronting', 2),
#  ('organization', 2),
#  ('source', 2),
#  ('pay', 2),
#  ('burden', 2),
#  ('fair', 2),
#  ('powerful', 2),
#  ('accountable', 2),
#  ('societies', 2),
#  ('cuba', 2),
#  ('cuban', 2),
#  ('socialist', 2),
#  ('suffering', 2),
#  ('destroyed', 2),
#  ('important', 2),
#  ('prepared', 2),
#  ('action', 2),
#  ('healthy', 2),
#  ('bond', 2),
#  ('implemented', 2),
#  ('sacrifice', 2),
#  ('distinguished', 1),
#  ('delegates', 1),
#  ('welcome', 1),
#  ('york', 1),
#  ('profound', 1),
#  ('honor', 1),
#  ('city', 1),
#  ('representative', 1),
#  ('suffer', 1),
#  ('effects', 1),
#  ('devastating', 1),
#  ('hurricanes', 1),
#  ('struck', 1),
#  ('expressing', 1),
#  ('appreciation', 1),
#  ('offered', 1),
#  ('aid', 1),
#  ('resilient', 1),
#  ('hardships', 1),
#  ('determined', 1),
#  ('\nfortunately', 1),
#  ('election', 1),
#  ('november', 1),
#  ('8', 1),
#  ('stock', 1),
#  ('market', 1),
#  ('all-time', 1),
#  ('high', 1),
#  ('record', 1),
#  ('unemployment', 1),
#  ('lowest', 1),
#  ('level', 1),
#  ('16', 1),
#  ('regulatory', 1),
#  ('companies', 1),
#  ('moving', 1),
#  ('creating', 1),
#  ('job', 1),
#  ('growth', 1),
#  ('likes', 1),
#  ('seen', 1),
#  ('spending', 1),
#  ('$700', 1),
#  ('billion', 1),
#  ('defense', 1),
#  ('strongest', 1),
#  ('times', 1),
#  ('movements', 1),
#  ('religions', 1),
#  ('assembly', 1),
#  ('\nlike', 1),
#  ('intend', 1),
#  ('enormous', 1),
#  ('potential', 1),
#  ('waiting', 1),
#  ('unleashed', 1),
#  ('extraordinary', 1),
#  ('breakthroughs', 1),
#  ('science', 1),
#  ('medicine', 1),
#  ('curing', 1),
#  ('illnesses', 1),
#  ('solving', 1),
#  ('prior', 1),
#  ('thought', 1),
#  ('impossible', 1),
#  ('brings', 1),
#  ('news', 1),
#  ('growing', 1),
#  ('cherish', 1),
#  ('value', 1),
#  ('extremists', 1),
#  ('destructive', 1),
#  ('known', 1),
#  ('\nauthority', 1),
#  ('powers', 1),
#  ('alliances', 1),
#  ('prevented', 1),
#  ('tilted', 1),
#  ('word', 1),
#  ('ii', 1),
#  ('networks', 1),
#  ('traffic', 1),
#  ('drugs', 1),
#  ('force', 1),
#  ('dislocation', 1),
#  ('aggression', 1),
#  ('exploit', 1),
#  ('menace', 1),
#  ('simply', 1),
#  ('meet', 1),
#  ('immense', 1),
#  ('peril', 1),
#  ('entirely', 1),
#  ('heights', 1),
#  ('fall', 1),
#  ('valley', 1),
#  ('disrepair', 1),
#  ('choose', 1),
#  ('raised', 1),
#  ('hatred', 1),
#  ('founded', 1),
#  ('aftermath', 1),
#  ('shape', 1),
#  ('cooperate', 1),
#  ('period', 1),
#  ('exactly', 1),
#  ('developed', 1),
#  ('built', 1),
#  ('idea', 1),
#  ('safer', 1),
#  ('congress', 1),
#  ('european', 1),
#  ('recovery', 1),
#  ('accord', 1),
#  ('perils', 1),
#  ('achieve', 1),
#  ('wisdom', 1),
#  ('coalition', 1),
#  ('traditions', 1),
#  ('core', 1),
#  ('coexist', 1),
#  ('basis', 1),
#  ('mutual', 1),
#  ('ownership', 1),
#  ('control', 1),
#  ('individuals', 1),
#  ('flourish', 1),
#  ('fullness', 1),
#  ('shine', 1),
#  ('week', 1),
#  ('gives', 1),
#  ('special', 1),
#  ('reason', 1),
#  ('celebrating', 1),
#  ('230th', 1),
#  ('anniversary', 1),
#  ('beloved', 1),
#  ('oldest', 1),
#  ('timeless', 1),
#  ('document', 1),
#  ('inspiration', 1),
#  ('nature', 1),
#  ('greatest', 1),
#  ('"we', 1),
#  ('people"', 1),
#  ('maintain', 1),
#  ('history\nin', 1),
#  ('govern', 1),
#  ('foreign', 1),
#  ('affairs', 1),
#  ("government's", 1),
#  ('needs', 1),
#  ('first\nall', 1),
#  ('obligation', 1),
#  ('remains', 1),
#  ('vehicle', 1),
#  ('elevating', 1),
#  ('condition', 1),
#  ('making', 1),
#  ('requires', 1),
#  ('unity', 1),
#  ('create', 1),
#  ('longer', 1),
#  ('advantage', 1),
#  ('enter', 1),
#  ('gets', 1),
#  ('office', 1),
#  ('fulfilling', 1),
#  ('obligations', 1),
#  ("it's", 1),
#  ("everyone's", 1),
#  ('\namerica', 1),
#  ('does', 1),
#  ('speak', 1),
#  ('expressed', 1),
#  ('charter', 1),
#  ('paid', 1),
#  ('ultimate', 1),
#  ('price', 1),
#  ('hall', 1),
#  ('devotion', 1),
#  ('measured', 1),
#  ('battlefields', 1),
#  ('young', 1),
#  ('alongside', 1),
#  ('beaches', 1),
#  ('deserts', 1),
#  ('jungles', 1),
#  ('asia', 1),
#  ('eternal', 1),
#  ('credit', 1),
#  ('character', 1),
#  ('victorious', 1),
#  ('bloodiest', 1),
#  ('did', 1),
#  ('territorial', 1),
#  ('expansion', 1),
#  ('attempt', 1),
#  ('oppose', 1),
#  ('instead', 1),
#  ('helped', 1),
#  ('friendship', 1),
#  ('strife', 1),
#  ('guided', 1),
#  ('outcomes', 1),
#  ('policy', 1),
#  ('principled', 1),
#  ('shared', 1),
#  ('facing', 1),
#  ('escape', 1),
#  ('avoid', 1),
#  ('slide', 1),
#  ('complacency', 1),
#  ('numb', 1),
#  ('enjoy', 1),
#  ('tomorrow', 1),
#  ('desire', 1),
#  ('aspire', 1),
#  ('approval', 1),
#  ('fulfill', 1),
#  ('represent', 1),
#  ('futures', 1),
#  ('reject', 1),
#  ('ukraine', 1),
#  ('sea', 1),
#  ('\nand', 1),
#  ('founders', 1),
#  ('turmoil', 1),
#  ('score', 1),
#  ('small', 1),
#  ('violate', 1),
#  ('righteous', 1),
#  ('wicked', 1),
#  ('triumph', 1),
#  ('bystanders', 1),
#  ('gather', 1),
#  ('strength\nno', 1),
#  ('shown', 1),
#  ('contempt', 1),
#  ('depraved', 1),
#  ('starvation', 1),
#  ('deaths', 1),
#  ('koreans', 1),
#  ('imprisonment', 1),
#  ('torture', 1),
#  ('killing', 1),
#  ('oppression', 1),
#  ('witness', 1),
#  ('deadly', 1),
#  ('abuse', 1),
#  ('college', 1),
#  ('otto', 1),
#  ('warmbier', 1),
#  ('returned', 1),
#  ('days', 1),
#  ('later', 1),
#  ('saw', 1),
#  ('assassination', 1),
#  ("dictator's", 1),
#  ('brother', 1),
#  ('using', 1),
#  ('nerve', 1),
#  ('agents', 1),
#  ('airport', 1),
#  ('know', 1),
#  ('kidnapped', 1),
#  ('sweet', 1),
#  ('13-year-old', 1),
#  ('japanese', 1),
#  ('girl', 1),
#  ('beach', 1),
#  ('enslave', 1),
#  ('language', 1),
#  ('tutor', 1),
#  ('spies', 1),
#  ('twisted', 1),
#  ('ballistic', 1),
#  ('unthinkable', 1),
#  ('loss', 1),
#  ('outrage', 1),
#  ('supply', 1),
#  ('imperils', 1),
#  ('\nno', 1),
#  ('earth', 1),
#  ('seeing', 1),
#  ('band', 1),
#  ('criminals', 1),
#  ('patience', 1),
#  ('forced', 1),
#  ('destroy', 1),
#  ('rocket', 1),
#  ('man', 1),
#  ('suicide', 1),
#  ('himself', 1),
#  ('ready', 1),
#  ('able', 1),
#  ('hopefully', 1),
#  ("let's", 1),
#  ('do\nit', 1),
#  ('denuclearization', 1),
#  ('acceptable', 1),
#  ('held', 1),
#  ('unanimous', 1),
#  ('15-0', 1),
#  ('votes', 1),
#  ('adopting', 1),
#  ('hard-hitting', 1),
#  ('resolutions', 1),
#  ('russia', 1),
#  ('joining', 1),
#  ('vote', 1),
#  ('involved', 1),
#  ('more\nit', 1),
#  ('isolate', 1),
#  ('kim', 1),
#  ('ceases', 1),
#  ('hostile', 1),
#  ('behavior', 1),
#  ('decision', 1),
#  ('korea;', 1),
#  ('speaks', 1),
#  ('openly', 1),
#  ('murder', 1),
#  ('vowing', 1),
#  ('israel', 1),
#  ('ruin', 1),
#  ('masks', 1),
#  ('false', 1),
#  ('guise', 1),
#  ('turned', 1),
#  ('wealthy', 1),
#  ('rich', 1),
#  ('economically', 1),
#  ('depleted', 1),
#  ('chief', 1),
#  ('exports', 1),
#  ('longest-suffering', 1),
#  ('victims', 1),
#  ('resources', 1),
#  ('improve', 1),
#  ('oil', 1),
#  ('profits', 1),
#  ('kill', 1),
#  ('muslims', 1),
#  ('attack', 1),
#  ('israeli', 1),
#  ('rightly', 1),
#  ('goes', 1),
#  ('shore', 1),
#  ("al-assad's", 1),
#  ('fuel', 1),
#  ("yemen's", 1),
#  ('civil', 1),
#  ('undermine', 1),
#  ('murderous', 1),
#  ('activities', 1),
#  ('building', 1),
#  ('dangerous', 1),
#  ('abide', 1),
#  ('agreement', 1),
#  ('provides', 1),
#  ('cover', 1),
#  ('construction', 1),
#  ('program', 1),
#  ('worst', 1),
#  ('transactions', 1),
#  ('entered', 1),
#  ('frankly', 1),
#  ("don't", 1),
#  ('think', 1),
#  ("you've", 1),
#  ('heard', 1),
#  ('me\nit', 1),
#  ('join', 1),
#  ('demanding', 1),
#  ('unjustly', 1),
#  ('detained', 1),
#  ('supporting', 1),
#  ('serving', 1),
#  ('understands', 1),
#  ('change', 1),
#  ('vast', 1),
#  ('causes', 1),
#  ('restrict', 1),
#  ('internet', 1),
#  ('access', 1),
#  ('satellite', 1),
#  ('dishes', 1),
#  ('shoot', 1),
#  ('unarmed', 1),
#  ('protesters', 1),
#  ('imprison', 1),
#  ('reformers', 1),
#  ('\noppressive', 1),
#  ('endure', 1),
#  ('come', 1),
#  ("nation's", 1),
#  ('proud', 1),
#  ('roots', 1),
#  ('center', 1),
#  ('civilization', 1),
#  ('happy', 1),
#  ('again?', 1),
#  ('stark', 1),
#  ('contrast', 1),
#  ('commitments', 1),
#  ('halt', 1),
#  ('saudi', 1),
#  ('arabia', 1),
#  ('early', 1),
#  ('year', 1),
#  ('greatly', 1),
#  ('honored', 1),
#  ('50', 1),
#  ('muslim', 1),
#  ('agreed', 1),
#  ('extremism', 1),
#  ('inspires', 1),
#  ('radical', 1),
#  ('deny', 1),
#  ('haven', 1),
#  ('transit', 1),
#  ('funding', 1),
#  ('form', 1),
#  ('vile', 1),
#  ('sinister', 1),
#  ('drive', 1),
#  ('expose', 1),
#  ('fi', 1),
#  ('groups', 1),
#  ('al-qaeda', 1),
#  ('slaughter', 1),
#  ('crush', 1),
#  ('loser', 1),
#  ('reemergence', 1),
#  ('havens', 1),
#  ('launch', 1),
#  ('attacks', 1),
#  ('month', 1),
#  ('strategy', 1),
#  ('afghanistan', 1),
#  ('dictate', 1),
#  ('length', 1),
#  ('scope', 1),
#  ('operation', 1),
#  ('arbitrary', 1),
#  ('benchmarks', 1),
#  ('timetables', 1),
#  ('set', 1),
#  ('politicians', 1),
#  ('changed', 1),
#  ('terrorist', 1),
#  ('groups\nin', 1),
#  ('syria', 1),
#  ('iraq', 1),
#  ('big', 1),
#  ('gains', 1),
#  ('lasting', 1),
#  ('defeat', 1),
#  ('achieved', 1),
#  ('months', 1),
#  ('combined', 1),
#  ('deescalation', 1),
#  ('solution', 1),
#  ('honors', 1),
#  ('actions', 1),
#  ('al-assad', 1),
#  ('shock', 1),
#  ('conscience', 1),
#  ('society', 1),
#  ('allowed', 1),
#  ('carried', 1),
#  ('missile', 1),
#  ('strike', 1),
#  ('airbase', 1),
#  ('launched', 1),
#  ('attack\nwe', 1),
#  ('appreciate', 1),
#  ('efforts', 1),
#  ('agencies', 1),
#  ('areas', 1),
#  ('liberated', 1),
#  ('jordan', 1),
#  ('turkey', 1),
#  ('lebanon', 1),
#  ('compassionate', 1),
#  ('spent', 1),
#  ('dollars', 1),
#  ('helping', 1),
#  ('effort', 1),
#  ('resettlement', 1),
#  ('designed', 1),
#  ('horribly', 1),
#  ('treated', 1),
#  ('enables', 1),
#  ('rebuilding', 1),
#  ('resettling', 1),
#  ('assist', 1),
#  ('10', 1),
#  ('\nout', 1),
#  ('goodness', 1),
#  ('offer', 1),
#  ('financial', 1),
#  ('agreements', 1),
#  ('g20', 1),
#  ('host', 1),
#  ('possible', 1),
#  ('decades', 1),
#  ('dealt', 1),
#  ('learned', 1),
#  ('term', 1),
#  ('deeply', 1),
#  ('reduces', 1),
#  ('domestic', 1),
#  ('pressure', 1),
#  ('needed', 1),
#  ('drains', 1),
#  ('capital', 1),
#  ('motivate', 1),
#  ('implement', 1),
#  ('substantial', 1),
#  ('costs', 1),
#  ('born', 1),
#  ('overwhelmingly', 1),
#  ('low-income', 1),
#  ('concerns', 1),
#  ('ignored', 1),
#  ('media', 1),
#  ('\ni', 1),
#  ('salute', 1),
#  ('seeking', 1),
#  ('cause', 1),
#  ('flee', 1),
#  ('african', 1),
#  ('peacekeeping', 1),
#  ('missions', 1),
#  ('invaluable', 1),
#  ('contributions', 1),
#  ('stabilizing', 1),
#  ('africa', 1),
#  ('continues', 1),
#  ('lead', 1),
#  ('famine', 1),
#  ('prevention', 1),
#  ('sudan', 1),
#  ('somalia', 1),
#  ('northern', 1),
#  ('nigeria', 1),
#  ('yemen', 1),
#  ('programs', 1),
#  ('pepfar', 1),
#  ('funds', 1),
#  ('aids', 1),
#  ('president’s', 1),
#  ('malaria', 1),
#  ('agenda', 1),
#  ('modern', 1),
#  ('slavery', 1),
#  ("entrepreneur's", 1),
#  ('empowering', 1),
#  ('recognizing', 1),
#  ('partner', 1),
#  ('focus', 1),
#  ('results', 1),
#  ('bureaucracy', 1),
#  ('cases', 1),
#  ('subvert', 1),
#  ("institution's", 1),
#  ('hijacked', 1),
#  ('supposed', 1),
#  ('advance', 1),
#  ('massive', 1),
#  ('governments', 1),
#  ('egregious', 1),
#  ('records', 1),
#  ('sit', 1),
#  ('193', 1),
#  ('22', 1),
#  ('percent', 1),
#  ('budget', 1),
#  ('anybody', 1),
#  ('realizes', 1),
#  ('bears', 1),
#  ('actually', 1),
#  ('accomplish', 1),
#  ('stated', 1),
#  ('goals', 1),
#  ('investment', 1),
#  ('easily', 1),
#  ('worth', 1),
#  ('major', 1),
#  ('portions', 1),
#  ('going', 1),
#  ('hell', 1),
#  ('guidance', 1),
#  ('auspices', 1),
#  ('vicious', 1),
#  ('complex', 1),
#  ('advocate', 1),
#  ('\nin', 1),
#  ('meantime', 1),
#  ('bear', 1),
#  ('disproportionate', 1),
#  ('militarily', 1),
#  ('greater', 1),
#  ('promoting', 1),
#  ('embraced', 1),
#  ('enduring', 1),
#  ('dream', 1),
#  ('\nmy', 1),
#  ('administration', 1),
#  ('makes', 1),
#  ('fundamental', 1),
#  ('imposed', 1),
#  ('tough', 1),
#  ('calibrated', 1),
#  ('brought', 1),
#  ('thriving', 1),
#  ('brink', 1),
#  ('total', 1),
#  ('nicolás', 1),
#  ('inflicted', 1),
#  ('terrible', 1),
#  ('pain', 1),
#  ('imposing', 1),
#  ('failed', 1),
#  ('produced', 1),
#  ('misery', 1),
#  ('tried', 1),
#  ('make', 1),
#  ('matters', 1),
#  ('worse', 1),
#  ('defied', 1),
#  ('stealing', 1),
#  ('representatives', 1),
#  ('disastrous', 1),
#  ('starving', 1),
#  ('collapsing', 1),
#  ('democratic', 1),
#  ('situation', 1),
#  ('completely', 1),
#  ('unacceptable', 1),
#  ('\nas', 1),
#  ('neighbor', 1),
#  ('regain', 1),
#  ('recover', 1),
#  ('condemning', 1),
#  ('steps', 1),
#  ('persists', 1),
#  ('people\nwe', 1),
#  ...]

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.3.1.tar.gz (169kB)
#     100% |████████████████████████████████| 174kB 94kB/s ta 0:00:01
# Collecting matplotlib (from wordcloud)
#   Downloading matplotlib-2.1.0-cp36-cp36m-manylinux1_x86_64.whl (15.0MB)
#     100% |████████████████████████████████| 15.0MB 50kB/s ta 0:00:014
# Collecting numpy>=1.6.1 (from wordcloud)
#   Downloading numpy-1.13.3-cp36-cp36m-manylinux1_x86_64.whl (17.0MB)
#     100% |████████████████████████████████| 17.0MB 58kB/s eta 0:00:01   31% |██████████                      | 5.4MB 87kB/s eta 0:02:14    37% |████████████▏                   | 6.4MB 62kB/s eta 0:02:49    62% |████████████████████            | 10.7MB 57kB/s eta 0:01:50
# Collecting pillow (from wordcloud)
#   Downloading Pillow-4.3.0-cp36-cp36m-manylinux1_x86_64.whl (5.8MB)
#     100% |████████████████████████████████| 5.8MB 25kB/s ta 0:00:014
# Collecting pytz (from matplotlib->wordcloud)
#   Downloading pytz-2017.2-py2.py3-none-any.whl (484kB)
#     100% |████████████████████████████████| 491kB 62kB/s ta 0:00:012
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 (from matplotlib->wordcloud)
#   Downloading pyparsing-2.2.0-py2.py3-none-any.whl (56kB)
#     100% |████████████████████████████████| 61kB 41kB/s ta 0:00:01
# Requirement already satisfied: python-dateutil>=2.0 in ./.pyenv/versions/3.6.1/lib/python3.6/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied: six>=1.10 in ./.pyenv/versions/3.6.1/lib/python3.6/site-packages (from matplotlib->wordcloud)
# Collecting cycler>=0.10 (from matplotlib->wordcloud)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl
# Collecting olefile (from pillow->wordcloud)
#   Downloading olefile-0.44.zip (74kB)
#     100% |████████████████████████████████| 81kB 78kB/s ta 0:00:01
# Installing collected packages: pytz, pyparsing, numpy, cycler, matplotlib, olefile, pillow, wordcloud
#   Running setup.py install for olefile ... done
#   Running setup.py install for wordcloud ... done
# Successfully installed cycler-0.10.0 matplotlib-2.1.0 numpy-1.13.3 olefile-0.44 pillow-4.3.0 pyparsing-2.2.0 pytz-2017.2 wordcloud-1.3.1

# %%
from wordcloud import WordCloud
wc = WordCloud(background_color='white').generate_from_frequencies(word_dict)

# %%
import matplotlib.pyplot as plt
plt.imshow(wc)

# %%
plt.show()
